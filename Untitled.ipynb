anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\91830\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\91830\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\91830\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\91830\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\91830\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\91830\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\91830\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\91830\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\91830\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\91830\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91830\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91830\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91830\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91830\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91830\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)

# %%
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os

def initial_llm():
    llm = ChatGroq(
    temperature = 0,
    groq_api_key = "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",
    model_name = "llama-3.3-70b-versatile"
)
    return llm

def create_db():
    loader = DirectoryLoader("./content/data/",glob= '*.pdf',loader_cls = PyPDFLoader)
    doc = loader.load()
    txt_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap = 50)
    txts = txt_splitter.split_documents(doc)
    embedd = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
    call_db = Chroma.from_documents(txts,embedd, persist_directory='./chroma_db')
    call_db.persist()
    print("ChromaDB created and data has been saved!!")
    
    return call_db

def setup_qachain(call_db,llm):
    retrieve = call_db.as_retriever()
    prompt_tmplt = """ Sharing your thoughts is a brave step. I'll respond with empathy and understanding:
 #   {context}
    User: {question}
    Chatbot: """
    PROMPT = PromptTemplate(template = prompt_tmplt, input_variable=['context','question'])
    
    qa_chain = RetrievalQA.from_chain_type(
        llm = llm,
        chain_type = "stuff",
        retriever = retrieve,
        chain_type_kwargs = {"prompt": PROMPT}
    )
    
    return qa_chain

def main():
    print("Initializing Chatbot....")
    llm = initial_llm()
    
    db_path = './chroma_db'
    
    if not os.path.exists(db_path):
        call_db = create_db()
    else:
        embedd = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
        call_db = Chroma(persist_directory=db_path,embedding_function=embedd)
    qa_chain = setup_qachain(call_db,llm)
    
    while True:
        query = input("\nHuman: ")
        if query.lower()=="exit":
            print("Chatbot: Take care of yourself. I am here to help anytime you need, Goodbye!!")
            break
        res = qa_chain.run(query)
        print(f"Chatbot: {res}")

if __name__=="__main__":
    main()
# Out:
# Initializing Chatbot....
# C:\Users\91830\AppData\Local\Temp\ipykernel_19788\3865746529.py:55: LangChainDeprecationWarning: The class `HuggingFaceBgeEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedd = HuggingFaceBgeEmbeddings(model_name = 'sentence-transformers/all-MiniLM-L6-v2')
# C:\Users\91830\AppData\Local\Temp\ipykernel_19788\3865746529.py:56: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   call_db = Chroma(persist_directory=db_path,embedding_function=embedd)
# Human:  exit
# Chatbot: Take care of yourself. I am here to help anytime you need, Goodbye!!

# %%
# !pip  install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.14.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (0.115.8)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.7.0 (from gradio)
#   Downloading gradio_client-1.7.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (3.10.15)
# Requirement already satisfied: packaging in c:\users\91830\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (2.8.2)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.9.4-py3-none-win_amd64.whl.metadata (26 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (0.45.3)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.15.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in c:\users\91830\anaconda3\lib\site-packages (from gradio-client==1.7.0->gradio) (2024.6.1)
# Requirement already satisfied: websockets<15.0,>=10.0 in c:\users\91830\anaconda3\lib\site-packages (from gradio-client==1.7.0->gradio) (14.2)
# Requirement already satisfied: idna>=2.8 in c:\users\91830\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\91830\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\91830\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\91830\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\91830\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\91830\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\91830\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\91830\anaconda3\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\91830\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91830\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\91830\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\91830\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\91830\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\91830\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\91830\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\91830\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\users\91830\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\91830\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\91830\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\91830\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91830\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91830\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\91830\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Downloading gradio-5.14.0-py3-none-any.whl (57.7 MB)
#    ---------------------------------------- 0.0/57.7 MB ? eta -:--:--
#    --- ------------------------------------ 5.5/57.7 MB 30.5 MB/s eta 0:00:02
#    ------ --------------------------------- 9.7/57.7 MB 24.1 MB/s eta 0:00:02
#    --------- ------------------------------ 13.9/57.7 MB 22.3 MB/s eta 0:00:02
#    ------------ --------------------------- 18.1/57.7 MB 21.5 MB/s eta 0:00:02
#    --------------- ------------------------ 22.0/57.7 MB 21.1 MB/s eta 0:00:02
#    ------------------ --------------------- 26.5/57.7 MB 21.0 MB/s eta 0:00:02
#    --------------------- ------------------ 30.7/57.7 MB 20.7 MB/s eta 0:00:02
#    ------------------------ --------------- 34.9/57.7 MB 20.5 MB/s eta 0:00:02
#    -------------------------- ------------- 38.8/57.7 MB 20.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 43.3/57.7 MB 20.2 MB/s eta 0:00:01
#    -------------------------------- ------- 47.4/57.7 MB 20.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 51.6/57.7 MB 20.2 MB/s eta 0:00:01
#    -------------------------------------- - 55.8/57.7 MB 20.1 MB/s eta 0:00:01
#    ---------------------------------------  57.7/57.7 MB 20.1 MB/s eta 0:00:01
#    ---------------------------------------- 57.7/57.7 MB 18.5 MB/s eta 0:00:00
# Downloading gradio_client-1.7.0-py3-none-any.whl (321 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.9.4-py3-none-win_amd64.whl (10.9 MB)
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    --------------------- ------------------ 5.8/10.9 MB 29.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/10.9 MB 23.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.9/10.9 MB 21.2 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading typer-0.15.1-py3-none-any.whl (44 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, tomlkit, semantic-version, ruff, python-multipart, ffmpy, aiofiles, typer, safehttpx, gradio-client, gradio
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
# Successfully installed aiofiles-23.2.1 ffmpy-0.5.0 gradio-5.14.0 gradio-client-1.7.0 pydub-0.25.1 python-multipart-0.0.20 ruff-0.9.4 safehttpx-0.1.6 semantic-version-2.10.0 tomlkit-0.13.2 typer-0.15.1

# %%
import os
print(os.listdir())
# Out:
# ['.gradio', '.ipynb_checkpoints', 'chroma_db', 'content', 'Untitled.ipynb']

# %%
# !pip uninstall pandas -y
# !pip install --no-cache-dir pandas
# Out:
# Found existing installation: pandas 2.2.2
# Uninstalling pandas-2.2.2:
#   Successfully uninstalled pandas-2.2.2
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\91830\anaconda3\Lib\site-packages\~andas'.
# You can safely remove it manually.
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\91830\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\91830\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91830\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\91830\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\91830\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ------------------ --------------------- 5.2/11.5 MB 31.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.5 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 24.0 MB/s eta 0:00:00
# Installing collected packages: pandas
# Successfully installed pandas-2.2.3

# %%
# !pip install --upgrade jupyter pandas
# Out:
# Requirement already satisfied: jupyter in c:\users\91830\anaconda3\lib\site-packages (1.0.0)
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pandas in c:\users\91830\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: notebook in c:\users\91830\anaconda3\lib\site-packages (from jupyter) (7.2.2)
# Requirement already satisfied: jupyter-console in c:\users\91830\anaconda3\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\91830\anaconda3\lib\site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\91830\anaconda3\lib\site-packages (from jupyter) (6.28.0)
# Requirement already satisfied: ipywidgets in c:\users\91830\anaconda3\lib\site-packages (from jupyter) (7.8.1)
# Requirement already satisfied: jupyterlab in c:\users\91830\anaconda3\lib\site-packages (from jupyter) (4.2.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\91830\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\91830\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91830\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\91830\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\91830\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\91830\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\91830\anaconda3\lib\site-packages (from ipywidgets->jupyter) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\91830\anaconda3\lib\site-packages (from ipywidgets->jupyter) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\91830\anaconda3\lib\site-packages (from ipywidgets->jupyter) (1.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-console->jupyter) (3.0.43)
# Requirement already satisfied: pygments in c:\users\91830\anaconda3\lib\site-packages (from jupyter-console->jupyter) (2.15.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab->jupyter) (0.27.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab->jupyter) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab->jupyter) (0.2.3)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab->jupyter) (75.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\91830\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: webencodings in c:\users\91830\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: anyio in c:\users\91830\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.2.0)
# Requirement already satisfied: certifi in c:\users\91830\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\91830\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.2)
# Requirement already satisfied: idna in c:\users\91830\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.7)
# Requirement already satisfied: sniffio in c:\users\91830\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\91830\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: decorator in c:\users\91830\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\91830\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\91830\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: colorama in c:\users\91830\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (305.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\91830\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\91830\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\91830\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\91830\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\91830\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\91830\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\91830\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\91830\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\91830\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\91830\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\91830\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\91830\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91830\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91830\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.3)
# Requirement already satisfied: executing in c:\users\91830\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\91830\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\91830\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\91830\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\91830\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\91830\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\91830\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.2.3)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, isoduration, jupyter
#   Attempting uninstall: jupyter
#     Found existing installation: jupyter 1.0.0
#     Uninstalling jupyter-1.0.0:
#       Successfully uninstalled jupyter-1.0.0
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 jupyter-1.1.1 uri-template-1.3.0 webcolors-24.11.1

# %%
import gradio as gr
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os

# Initialize LLM
from langchain_groq import ChatGroq  # Assuming ChatGroq is available

def initial_llm():
    llm = ChatGroq(
        temperature=0,
        groq_api_key="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",
        model_name="llama-3.3-70b-versatile"
    )
    return llm

def create_db():
    loader = DirectoryLoader("./", glob='*.pdf', loader_cls=PyPDFLoader)
    docs = loader.load()
    txt_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    txts = txt_splitter.split_documents(docs)
    embedd = HuggingFaceBgeEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
    call_db = Chroma.from_documents(txts, embedd, persist_directory='./chroma_db')
    call_db.persist()
    print("ChromaDB created and data has been saved!!")
    return call_db

def setup_qachain(call_db, llm):
    retrieve = call_db.as_retriever()
    prompt_tmplt = """Sharing your thoughts is a brave step. I'll respond with empathy and understanding:
    {context}
    User: {question}
    Chatbot: """
    PROMPT = PromptTemplate(template=prompt_tmplt, input_variables=['context', 'question'])
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retrieve,
        chain_type_kwargs={"prompt": PROMPT}
    )
    return qa_chain

# Load or create database
db_path = './chroma_db'
if not os.path.exists(db_path):
    call_db = create_db()
else:
    embedd = HuggingFaceBgeEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
    call_db = Chroma(persist_directory=db_path, embedding_function=embedd)

llm = initial_llm()
qa_chain = setup_qachain(call_db, llm)

def chatbot_response(query, history):
    if query.lower() == "exit":
        return "Take care of yourself. I am here to help anytime you need. Goodbye! 😊"
    response = qa_chain.run(query)
    history.append((query, response))
    return "", history

# Gradio Interface
def launch_chatbot():
    with gr.Blocks() as demo:
        gr.Markdown("# HARMONY.AI - 🧠 A Mental Health AI Chatbot")
        gr.Markdown("Chatbot powered by LangChain, ChromaDB, and Llama-3. Ask anything!!!")
        chatbot = gr.Chatbot()
        query_input = gr.Textbox(placeholder="Ask a question...")
        submit_button = gr.Button("Send")
        
        submit_button.click(chatbot_response, inputs=[query_input, chatbot], outputs=[query_input, chatbot])
        
        gr.Markdown("---")
        gr.Markdown("### Made By: Ashmit Jain")
        gr.Markdown("[GitHub](https://github.com/AshmitJain10/Mental-Health-AI-Chatbot)")
        
    demo.launch(share=True)

launch_chatbot()
# Out:
# C:\Users\91830\anaconda3\Lib\site-packages\gradio\components\chatbot.py:282: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://23f497d581d38f31fe.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://23f497d581d38f31fe.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
